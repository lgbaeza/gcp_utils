# %% [markdown]
# # Strategic Site Selection: Leveraging Geospatial Analytics at Scale
# @Luis Gerardo Baeza
#
#
# In industries with physical footprints—such as banking and retail—deciding where to open a new branch isn't just a "gut feeling" anymore; it's a data-driven science. By analyzing transactional data and geographic patterns, companies can transform raw coordinates into strategic assets.
#
# **Core Objectives**
# - Identify Demand: Map transaction "hotspots" to find where customers need a physical presence.
# - Prevent Cannibalization: Ensure a new location captures new market share instead of just stealing traffic from your existing branches.
# - Geospatial Intelligence: Use Google Maps for high-precision geocoding and BigQuery’s GEOGRAPHY functions to analyze spatial relationships at scale.
#
# **Why this Workflow?**
# - Speed: Process millions of transactions in seconds.
# - Scale: Analyze entire cities or countries simultaneously.
# - Accuracy: Use real-world coordinates to minimize the risk of expensive real estate mistakes.
#
# ## 1. Setup Google Maps
# ### 1.1 Dependencies

# %%
pip install -q googlemaps
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for googlemaps (setup.py) ... done

# %% [markdown]
# ### 1.2 Imports

# %%
import os
import sys
import pandas as pd
# Maps
import googlemaps
from typing import Iterator
from pyspark.sql.functions import pandas_udf, col, expr
# PySpark
from google.cloud.dataproc_spark_connect import DataprocSparkSession
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType, StructField, StringType

spark = DataprocSparkSession.builder \
    .getOrCreate()
spark.addArtifacts("googlemaps", pypi=True)
# Out:
# sc-20260213-163237-qhkzgg Dataproc Session is not active, stopping and creating a new one
#                 <div>
#                     <p>Creating Dataproc Spark Session<p>
#                     <p><a href="https://console.cloud.google.com/dataproc/interactive/us-central1/sc-20260213-174620-ohx8df?project=lgbaeza-202310">Dataproc Session</a></p>
#                 </div>
#
#     <link rel="stylesheet" href="https://fonts.googleapis.com/icon?family=Material+Icons">
#     <style>
#       .view-vertex-resource,
#       .view-vertex-resource:hover,
#       .view-vertex-resource:visited {
#         position: relative;
#         display: inline-flex;
#         flex-direction: row;
#         height: 32px;
#         padding: 0 12px;
#           margin: 4px 18px;
#         gap: 4px;
#         border-radius: 4px;
#
#         align-items: center;
#         justify-content: center;
#         background-color: rgb(255, 255, 255);
#         color: rgb(51, 103, 214);
#
#         font-family: Roboto,"Helvetica Neue",sans-serif;
#         font-size: 13px;
#         font-weight: 500;
#         text-transform: uppercase;
#         text-decoration: none !important;
#
#         transition: box-shadow 280ms cubic-bezier(0.4, 0, 0.2, 1) 0s;
#         box-shadow: 0px 3px 1px -2px rgba(0,0,0,0.2), 0px 2px 2px 0px rgba(0,0,0,0.14), 0px 1px 5px 0px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active {
#         box-shadow: 0px 5px 5px -3px rgba(0,0,0,0.2),0px 8px 10px 1px rgba(0,0,0,0.14),0px 3px 14px 2px rgba(0,0,0,0.12);
#       }
#       .view-vertex-resource:active .view-vertex-ripple::before {
#         position: absolute;
#         top: 0;
#         bottom: 0;
#         left: 0;
#         right: 0;
#         border-radius: 4px;
#         pointer-events: none;
#
#         content: '';
#         background-color: rgb(51, 103, 214);
#         opacity: 0.12;
#       }
#       .view-vertex-icon {
#         font-size: 18px;
#       }
#     </style>
#
#         <a class="view-vertex-resource" id="view-vertex-resource-88a5abf4-9a8f-43aa-84ae-4ac6211f1346" href="#view-view-vertex-resource-88a5abf4-9a8f-43aa-84ae-4ac6211f1346">
#           <span class="material-icons view-vertex-icon">dashboard</span>
#           <span>View Session Details</span>
#         </a>
#
#         <script>
#           (function () {
#             const link = document.getElementById('view-vertex-resource-88a5abf4-9a8f-43aa-84ae-4ac6211f1346');
#             link.addEventListener('click', (e) => {
#               if (window.google?.colab?.openUrl) {
#                 window.google.colab.openUrl('https://console.cloud.google.com/dataproc/interactive/sessions/sc-20260213-174620-ohx8df/locations/us-central1?project=lgbaeza-202310');
#               } else {
#                 window.open('https://console.cloud.google.com/dataproc/interactive/sessions/sc-20260213-174620-ohx8df/locations/us-central1?project=lgbaeza-202310', '_blank');
#               }
#               e.stopPropagation();
#               e.preventDefault();
#             });
#           })();
#         </script>
# █████████████████████████████████████████████████▌
# <div><p>Dataproc Session was successfully created</p></div>

# %% [markdown]
# ### 1.3 Variables

# %%
api_key = ""
project_id = ""
location_id = "us-central1"
INPUT_TABLE = f"{project_id}.retail_geodemo.retail_sale_point"
OUTPUT_TABLE = f"{project_id}.retail_geodemo.retail_sale_point_enriched"

# %% [markdown]
# ## 2. Prepare sample data

# %%
# %%bigquery
# CREATE SCHEMA IF NOT EXISTS retail_geodemo;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# CREATE OR REPLACE TABLE `retail_geodemo.retail_areas` AS
# WITH raw_areas AS (
#   SELECT 1 as id, 'STGOC' as number_area, ST_GEOGFROMTEXT('MULTIPOLYGON(((-70.655 -33.448, -70.650 -33.448, -70.650 -33.452, -70.655 -33.452, -70.655 -33.448)))') as area_polygon
#   UNION ALL
#   SELECT 2, 'PROVI', ST_GEOGFROMTEXT('MULTIPOLYGON(((-70.615 -33.428, -70.610 -33.428, -70.610 -33.432, -70.615 -33.432, -70.615 -33.428)))')
#   UNION ALL
#   SELECT 3, 'LCONC', ST_GEOGFROMTEXT('MULTIPOLYGON(((-70.580 -33.400, -70.570 -33.400, -70.570 -33.410, -70.580 -33.410, -70.580 -33.400)))')
#   UNION ALL
#   SELECT 4, 'MAIPU', ST_GEOGFROMTEXT('MULTIPOLYGON(((-70.760 -33.500, -70.750 -33.500, -70.750 -33.510, -70.760 -33.510, -70.760 -33.500)))')
#   UNION ALL
#   SELECT 5, 'PALTO', ST_GEOGFROMTEXT('MULTIPOLYGON(((-70.580 -33.580, -70.570 -33.580, -70.570 -33.590, -70.580 -33.590, -70.580 -33.580)))')
#   UNION ALL
#   -- Generación de 45 áreas adicionales aleatorias en Chile (Rango lat -18 a -53)
#   SELECT
#     n,
#     RPAD(UPPER(SUBSTR(CAST(GENERATE_UUID() AS STRING), 1, 5)), 5, 'X'),
#     ST_GEOGFROMTEXT(FORMAT('MULTIPOLYGON(((%.3f %.3f, %.3f %.3f, %.3f %.3f, %.3f %.3f, %.3f %.3f)))',
#       -71.0 - (n*0.1), -30.0 - (n*0.2),
#       -70.9 - (n*0.1), -30.0 - (n*0.2),
#       -70.9 - (n*0.1), -30.1 - (n*0.2),
#       -71.0 - (n*0.1), -30.1 - (n*0.2),
#       -71.0 - (n*0.1), -30.0 - (n*0.2)))
#   FROM UNNEST(GENERATE_ARRAY(6, 50)) AS n
# )
# SELECT * FROM raw_areas;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# SELECT * FROM retail_geodemo.retail_areas;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#     id number_area                                       area_polygon
# 0   26       136F4  POLYGON((-73.6 -35.3, -73.5 -35.3, -73.5 -35.2...
# 1   31       2F35D  POLYGON((-74.1 -36.3, -74 -36.3, -74 -36.2, -7...
# 2   44       4B1F1  POLYGON((-75.4 -38.9, -75.3 -38.9, -75.3 -38.8...
# 3   38       BAF60  POLYGON((-74.8 -37.7, -74.7 -37.7, -74.7 -37.6...
# 4    1       STGOC  POLYGON((-70.655 -33.452, -70.65 -33.452, -70....
# 5   18       B83AE  POLYGON((-72.8 -33.7, -72.7 -33.7, -72.7 -33.6...
# 6   46       057AD  POLYGON((-75.6 -39.3, -75.5 -39.3, -75.5 -39.2...
# 7   19       82066  POLYGON((-72.9 -33.9, -72.8 -33.9, -72.8 -33.8...
# 8   13       8A2D4  POLYGON((-72.3 -32.7, -72.2 -32.7, -72.2 -32.6...
# 9   25       B2D84  POLYGON((-73.5 -35.1, -73.4 -35.1, -73.4 -35, ...
# 10  10       F4150  POLYGON((-72 -32.1, -71.9 -32.1, -71.9 -32, -7...
# 11  20       03FB9  POLYGON((-73 -34.1, -72.9 -34.1, -72.9 -34, -7...
# 12  34       93681  POLYGON((-74.4 -36.9, -74.3 -36.9, -74.3 -36.8...
# 13  16       9083C  POLYGON((-72.6 -33.3, -72.5 -33.3, -72.5 -33.2...
# 14   8       C5FEB  POLYGON((-71.8 -31.7, -71.7 -31.7, -71.7 -31.6...
# 15  35       997F4  POLYGON((-74.5 -37.1, -74.4 -37.1, -74.4 -37, ...
# 16  39       3897D  POLYGON((-74.9 -37.9, -74.8 -37.9, -74.8 -37.8...
# 17  49       D16CD  POLYGON((-75.9 -39.9, -75.8 -39.9, -75.8 -39.8...
# 18   9       5DC20  POLYGON((-71.9 -31.9, -71.8 -31.9, -71.8 -31.8...
# 19  42       E3DFA  POLYGON((-75.2 -38.5, -75.1 -38.5, -75.1 -38.4...
# 20  50       F6955  POLYGON((-76 -40.1, -75.9 -40.1, -75.9 -40, -7...
# 21  47       28D41  POLYGON((-75.7 -39.5, -75.6 -39.5, -75.6 -39.4...
# 22  12       83926  POLYGON((-72.2 -32.5, -72.1 -32.5, -72.1 -32.4...
# 23  30       BBC64  POLYGON((-74 -36.1, -73.9 -36.1, -73.9 -36, -7...
# 24  27       F0C5F  POLYGON((-73.7 -35.5, -73.6 -35.5, -73.6 -35.4...
# 25  36       AF8B0  POLYGON((-74.6 -37.3, -74.5 -37.3, -74.5 -37.2...
# 26  22       CCCB2  POLYGON((-73.2 -34.5, -73.1 -34.5, -73.1 -34.4...
# 27  23       BBFEA  POLYGON((-73.3 -34.7, -73.2 -34.7, -73.2 -34.6...
# 28  33       B7180  POLYGON((-74.3 -36.7, -74.2 -36.7, -74.2 -36.6...
# 29  43       6E9A9  POLYGON((-75.3 -38.7, -75.2 -38.7, -75.2 -38.6...
# 30   3       LCONC  POLYGON((-70.58 -33.41, -70.57 -33.41, -70.57 ...
# 31   7       E13F6  POLYGON((-71.7 -31.5, -71.6 -31.5, -71.6 -31.4...
# 32   5       PALTO  POLYGON((-70.58 -33.59, -70.57 -33.59, -70.57 ...
# 33  15       F0639  POLYGON((-72.5 -33.1, -72.4 -33.1, -72.4 -33, ...
# 34   6       D981B  POLYGON((-71.6 -31.3, -71.5 -31.3, -71.5 -31.2...
# 35  14       3D5D3  POLYGON((-72.4 -32.9, -72.3 -32.9, -72.3 -32.8...
# 36  37       54ECE  POLYGON((-74.7 -37.5, -74.6 -37.5, -74.6 -37.4...
# 37  11       95937  POLYGON((-72.1 -32.3, -72 -32.3, -72 -32.2, -7...
# 38  24       D3D43  POLYGON((-73.4 -34.9, -73.3 -34.9, -73.3 -34.8...
# 39   4       MAIPU  POLYGON((-70.76 -33.51, -70.75 -33.51, -70.75 ...
# 40  29       4737F  POLYGON((-73.9 -35.9, -73.8 -35.9, -73.8 -35.8...
# 41  28       C594D  POLYGON((-73.8 -35.7, -73.7 -35.7, -73.7 -35.6...
# 42  45       1BD03  POLYGON((-75.5 -39.1, -75.4 -39.1, -75.4 -39, ...
# 43  21       E9B6B  POLYGON((-73.1 -34.3, -73 -34.3, -73 -34.2, -7...
# 44   2       PROVI  POLYGON((-70.615 -33.432, -70.61 -33.432, -70....
# 45  40       A6CA6  POLYGON((-75 -38.1, -74.9 -38.1, -74.9 -38, -7...
# 46  48       5B164  POLYGON((-75.8 -39.7, -75.7 -39.7, -75.7 -39.6...
# 47  17       AF9E5  POLYGON((-72.7 -33.5, -72.6 -33.5, -72.6 -33.4...
# 48  41       0ADB2  POLYGON((-75.1 -38.3, -75 -38.3, -75 -38.2, -7...
# 49  32       CCC0F  POLYGON((-74.2 -36.5, -74.1 -36.5, -74.1 -36.4...

# %% [markdown]
# Podemos visualizar las areas con [BigQuery GeoViz](https://bigquerygeoviz.appspot.com/)
#
# ![areas_polygons.png](areas_polygons.png)

# %%
# %%bigquery
# CREATE OR REPLACE TABLE `retail_geodemo.retail_sale_point` AS
# WITH seed_data AS (
#   -- Usamos comillas dobles para evitar el error con O'Higgins
#   SELECT "Avenida Libertador Bernardo O'Higgins" as calle, "Santiago" as comuna, "Región Metropolitana" as region UNION ALL
#   SELECT "Calle Vicuña Mackenna", "La Florida", "Región Metropolitana" UNION ALL
#   SELECT "Avenida Apoquindo", "Las Condes", "Región Metropolitana" UNION ALL
#   SELECT "Avenida Pajaritos", "Maipú", "Región Metropolitana" UNION ALL
#   SELECT "Calle Prat", "Antofagasta", "Antofagasta" UNION ALL
#   SELECT "Avenida Libertad", "Viña del Mar", "Valparaíso" UNION ALL
#   SELECT "Calle Diego Portales", "Temuco", "Araucanía" UNION ALL
#   SELECT "Avenida Alemania", "Concepción", "Biobío" UNION ALL
#   SELECT "Calle Baquedano", "Iquique", "Tarapacá" UNION ALL
#   SELECT "Avenida Costanera", "Puerto Montt", "Los Lagos"
# ),
# generator AS (
#   SELECT n FROM UNNEST(GENERATE_ARRAY(1, 2000)) n
# ),
# numbered_seeds AS (
#   SELECT *, ROW_NUMBER() OVER() as seed_id FROM seed_data
# ),
# total_seeds AS (
#   SELECT COUNT(*) as cnt FROM seed_data
# )
# SELECT
#   GENERATE_UUID() as id,
#   -- Combinamos calle + espacio + número aleatorio
#   CONCAT(s.calle, " ", CAST(FLOOR(RAND() * 9999) + 1 AS INT64)) as direccion,
#   s.comuna,
#   s.region
# FROM generator g
# CROSS JOIN total_seeds t
# JOIN numbered_seeds s
#   ON MOD(g.n, t.cnt) + 1 = s.seed_id;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# SELECT * FROM retail_geodemo.retail_sale_point LIMIT 50;
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                       id  \
# 0   10e7697e-f80c-4859-8784-bb64f2a43f9a
# 1   2f63e2af-8d05-4692-bf5e-0024d8280bc5
# 2   ec76e800-901b-46df-88b1-5be40956810c
# 3   4e6d84b4-1cfd-40b9-bc53-e22e866b3829
# 4   ab101f4c-55f4-4ae6-a7ca-b97bbcde2027
# 5   2d873b44-3161-4339-a69d-41c485241cb1
# 6   af03f38b-4733-47d9-971b-1978c6d88a6a
# 7   04f5c6ab-c33c-471b-8555-007777c835a6
# 8   6bd5cbe3-0321-4928-8a92-1ab98bed4148
# 9   ae8ebe0d-628c-42a8-9511-bcbfe669c772
# 10  dddbd6e3-c419-4a09-bb75-f7b06399a742
# 11  ae5d8c83-c3e9-4602-8bba-635f7026db0d
# 12  f6491195-16ad-4b3f-b654-c02a247da951
# 13  95381d41-ad7e-42ba-8dad-2e1824bdc646
# 14  72d98751-a516-45b8-9205-5c1e7fb5a0ee
# 15  3bc610f9-b9f5-48a4-bb05-8af1eef721ba
# 16  133fcbd6-c7a5-492b-a74a-f3c1c3f2223f
# 17  72089653-d682-428e-ac8b-c15640882242
# 18  b3b324f1-47d5-4c01-b97f-905e0a7faa26
# 19  d4e130cc-02cc-4d39-8813-bd6b79ccd27d
# 20  589056c4-c991-4a33-b629-720abac54e41
# 21  f6edc839-6939-4659-a828-fcab71cf69ba
# 22  635eb34e-572d-4a01-9d0f-4feb789fa1ed
# 23  55311921-dc8c-41c8-8581-5560a2d7d049
# 24  3db6bdf8-dcca-418b-8edf-f6cbbc481cad
# 25  fab974bc-719c-42ba-a80f-81cf8bdc7a16
# 26  1a288780-4f6c-42cd-986a-9b759445033d
# 27  6d2fbf70-450f-4aef-83c3-d34be375d50b
# 28  a86314bc-9783-42b2-8dca-5055b71453ba
# 29  52763def-2de6-4703-8bb2-6d1668078e63
# 30  220128a0-a033-40f9-aa7e-3399e19a3d81
# 31  c15ee539-4aa1-4e1f-8a47-936f75919622
# 32  9fbdb1b9-e901-491c-9ebb-6dba70ab3bed
# 33  79854b74-e1db-4871-be5c-24ae5697b8ed
# 34  a174f946-1163-405b-9a3d-e190fcb4b174
# 35  06ca9f85-13ec-46ad-bd7c-9ee48d642186
# 36  4a6308ae-02ad-40d5-9099-a684258d9b00
# 37  809c7271-df64-4d72-8c00-8ff718f98ac1
# 38  3fee692e-5d57-4d1a-af92-09bf70e94059
# 39  70de38d1-2735-4747-95e8-cc252cf41257
# 40  a2b5de37-a7e9-4371-853d-afc8c1a01e3b
# 41  ce7f887c-0054-457f-807a-38cee094302b
# 42  e17becef-b60d-42f1-949a-d7939bbefcd9
# 43  a717ebe4-3aca-4918-a6f9-0d47243dbe65
# 44  d3012c53-e699-4c30-bd7b-baef29d2600e
# 45  3daf4ec7-b469-413a-91b2-a939cfd195a4
# 46  de7ea988-9e4a-41cc-8853-b882d087da0d
# 47  3ea722ee-a5a8-4a0f-923c-89bb84562729
# 48  92741b8f-8890-4e24-9ca9-dc6495c2635e
# 49  ada0c746-f351-4de0-8d3a-b94956de04d3
#
#                                      direccion        comuna  \
# 0                         Calle Baquedano 4236       Iquique
# 1                        Avenida Libertad 1638  Viña del Mar
# 2                         Calle Baquedano 9081       Iquique
# 3                         Calle Baquedano 1708       Iquique
# 4                              Calle Prat 3833   Antofagasta
# 5                              Calle Prat 8186   Antofagasta
# 6                       Avenida Apoquindo 6204    Las Condes
# 7                    Calle Diego Portales 3106        Temuco
# 8                        Avenida Alemania 5588    Concepción
# 9                    Calle Diego Portales 6709        Temuco
# 10                       Avenida Alemania 7641    Concepción
# 11                        Calle Baquedano 7750       Iquique
# 12  Avenida Libertador Bernardo O'Higgins 4200      Santiago
# 13                      Avenida Pajaritos 8936         Maipú
# 14                   Calle Diego Portales 9869        Temuco
# 15                        Calle Baquedano 5233       Iquique
# 16                       Avenida Libertad 4362  Viña del Mar
# 17                             Calle Prat 4381   Antofagasta
# 18                       Avenida Alemania 6123    Concepción
# 19                             Calle Prat 1904   Antofagasta
# 20                        Calle Baquedano 1557       Iquique
# 21                      Avenida Apoquindo 6653    Las Condes
# 22                        Calle Baquedano 7035       Iquique
# 23                      Avenida Apoquindo 4148    Las Condes
# 24                       Avenida Alemania 2886    Concepción
# 25                      Avenida Apoquindo 2356    Las Condes
# 26                  Calle Vicuña Mackenna 7952    La Florida
# 27                      Avenida Pajaritos 4665         Maipú
# 28                      Avenida Pajaritos 9048         Maipú
# 29                   Calle Diego Portales 5629        Temuco
# 30                       Avenida Libertad 4985  Viña del Mar
# 31                       Avenida Libertad 3170  Viña del Mar
# 32  Avenida Libertador Bernardo O'Higgins 7431      Santiago
# 33                      Avenida Costanera 3868  Puerto Montt
# 34  Avenida Libertador Bernardo O'Higgins 5054      Santiago
# 35                      Avenida Apoquindo 3180    Las Condes
# 36                      Avenida Pajaritos 6931         Maipú
# 37                        Calle Baquedano 2816       Iquique
# 38                  Calle Vicuña Mackenna 4443    La Florida
# 39                      Avenida Pajaritos 1408         Maipú
# 40                      Avenida Costanera 9140  Puerto Montt
# 41  Avenida Libertador Bernardo O'Higgins 5625      Santiago
# 42                        Calle Baquedano 6272       Iquique
# 43                      Avenida Costanera 8169  Puerto Montt
# 44                   Calle Diego Portales 8129        Temuco
# 45                       Avenida Libertad 4639  Viña del Mar
# 46                      Avenida Apoquindo 7782    Las Condes
# 47                             Calle Prat 1118   Antofagasta
# 48                      Avenida Apoquindo 8259    Las Condes
# 49                  Calle Vicuña Mackenna 3589    La Florida
#
#                   region
# 0               Tarapacá
# 1             Valparaíso
# 2               Tarapacá
# 3               Tarapacá
# 4            Antofagasta
# 5            Antofagasta
# 6   Región Metropolitana
# 7              Araucanía
# 8                 Biobío
# 9              Araucanía
# 10                Biobío
# 11              Tarapacá
# 12  Región Metropolitana
# 13  Región Metropolitana
# 14             Araucanía
# 15              Tarapacá
# 16            Valparaíso
# 17           Antofagasta
# 18                Biobío
# 19           Antofagasta
# 20              Tarapacá
# 21  Región Metropolitana
# 22              Tarapacá
# 23  Región Metropolitana
# 24                Biobío
# 25  Región Metropolitana
# 26  Región Metropolitana
# 27  Región Metropolitana
# 28  Región Metropolitana
# 29             Araucanía
# 30            Valparaíso
# 31            Valparaíso
# 32  Región Metropolitana
# 33             Los Lagos
# 34  Región Metropolitana
# 35  Región Metropolitana
# 36  Región Metropolitana
# 37              Tarapacá
# 38  Región Metropolitana
# 39  Región Metropolitana
# 40             Los Lagos
# 41  Región Metropolitana
# 42              Tarapacá
# 43             Los Lagos
# 44             Araucanía
# 45            Valparaíso
# 46  Región Metropolitana
# 47           Antofagasta
# 48  Región Metropolitana
# 49  Región Metropolitana

# %% [markdown]
# ##3. Maps Geocoding

# %%
def geocode_address(address):
  gmaps = googlemaps.Client(key=api_key)
  geocode_result = gmaps.geocode(address)
  latitude = geocode_result[0]['geometry']['location']['lat']
  longitude = geocode_result[0]['geometry']['location']['lng']

  return latitude, longitude

# %%
latitude, longitude = geocode_address(address = "Cerro el plomo 5680")
print(f"Latitude: {latitude}, Longitude: {longitude}")
# Out:
# Latitude: -33.4053637, Longitude: -70.5737473

# %% [markdown]
# ##3. PySpark processing at scale

# %%
@pandas_udf("string")
def geocode_udf(batch_iter: Iterator[pd.Series]) -> Iterator[pd.Series]:
    client = googlemaps.Client(key=api_key)
    for batch in batch_iter:
        yield batch.apply(lambda addr:
            f"POINT({client.geocode(addr)[0]['geometry']['location']['lng']} {client.geocode(addr)[0]['geometry']['location']['lat']})"
            if client.geocode(addr) else None)

# %%
df_prepared = spark.read.format("bigquery") \
    .option("query", f"""
        SELECT *, CONCAT(direccion, ', ', comuna, ', ', region, ', Chile') as full_address
        FROM `{project_id}.retail_geodemo.retail_sale_point`
    """).load()

# %%
df_intermediate = df_prepared.withColumn("wkt", geocode_udf(col("full_address")))
df_intermediate.show()
# Out:
#               <div>
#                   <p><a href="https://console.cloud.google.com/dataproc/interactive/us-central1/sc-20260213-163237-qhkzgg/sparkApplications/application;associatedSqlOperationId=574902c6-40f2-428f-97ed-24d05a41cfc9?project=lgbaeza-202310">Spark Query</a> (Operation: 574902c6-40f2-428f-97ed-24d05a41cfc9)</p>
#               </div>
# +--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# |                  id|           direccion|      comuna|              region|        full_address|                 wkt|
# +--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# |10e7697e-f80c-485...|Calle Baquedano 4236|     Iquique|            Tarapacá|Calle Baquedano 4...|POINT(-70.1521233...|
# |2f63e2af-8d05-469...|Avenida Libertad ...|Viña del Mar|          Valparaíso|Avenida Libertad ...|POINT(-71.5485564...|
# |ec76e800-901b-46d...|Calle Baquedano 9081|     Iquique|            Tarapacá|Calle Baquedano 9...|POINT(-70.1521233...|
# |4e6d84b4-1cfd-40b...|Calle Baquedano 1708|     Iquique|            Tarapacá|Calle Baquedano 1...|POINT(-70.1521542...|
# |ab101f4c-55f4-4ae...|     Calle Prat 3833| Antofagasta|         Antofagasta|Calle Prat 3833, ...|POINT(-70.3939298...|
# |2d873b44-3161-433...|     Calle Prat 8186| Antofagasta|         Antofagasta|Calle Prat 8186, ...|POINT(-70.3939298...|
# |af03f38b-4733-47d...|Avenida Apoquindo...|  Las Condes|Región Metropolitana|Avenida Apoquindo...|POINT(-70.5663508...|
# |04f5c6ab-c33c-471...|Calle Diego Porta...|      Temuco|           Araucanía|Calle Diego Porta...|POINT(-72.5717336...|
# |6bd5cbe3-0321-492...|Avenida Alemania ...|  Concepción|              Biobío|Avenida Alemania ...|POINT(-73.0489873...|
# |ae8ebe0d-628c-42a...|Calle Diego Porta...|      Temuco|           Araucanía|Calle Diego Porta...|POINT(-72.584812 ...|
# |dddbd6e3-c419-4a0...|Avenida Alemania ...|  Concepción|              Biobío|Avenida Alemania ...|POINT(-73.0489873...|
# |ae5d8c83-c3e9-460...|Calle Baquedano 7750|     Iquique|            Tarapacá|Calle Baquedano 7...|POINT(-70.1521233...|
# |f6491195-16ad-4b3...|Avenida Libertado...|    Santiago|Región Metropolitana|Avenida Libertado...|POINT(-70.6933394...|
# |95381d41-ad7e-42b...|Avenida Pajaritos...|       Maipú|Región Metropolitana|Avenida Pajaritos...|POINT(-70.7358633...|
# |72d98751-a516-45b...|Calle Diego Porta...|      Temuco|           Araucanía|Calle Diego Porta...|POINT(-72.584812 ...|
# |3bc610f9-b9f5-48a...|Calle Baquedano 5233|     Iquique|            Tarapacá|Calle Baquedano 5...|POINT(-70.1521233...|
# |133fcbd6-c7a5-492...|Avenida Libertad ...|Viña del Mar|          Valparaíso|Avenida Libertad ...|POINT(-71.5500805...|
# |72089653-d682-428...|     Calle Prat 4381| Antofagasta|         Antofagasta|Calle Prat 4381, ...|POINT(-70.3939298...|
# |b3b324f1-47d5-4c0...|Avenida Alemania ...|  Concepción|              Biobío|Avenida Alemania ...|POINT(-73.0489873...|
# |d4e130cc-02cc-4d3...|     Calle Prat 1904| Antofagasta|         Antofagasta|Calle Prat 1904, ...|POINT(-70.3880156...|
# +--------------------+--------------------+------------+--------------------+--------------------+--------------------+
# only showing top 20 rows

# %%
# 6. Write back to BigQuery
# 'indirect' write method via GCS is recommended for massive volumes (> 10GB)
# If using 'direct', ensure your project has enough BigQuery Write API quota
df_intermediate.write.format("bigquery") \
    .option("table", OUTPUT_TABLE) \
    .option("writeMethod", "direct") \
    .mode("overwrite") \
    .save()

print(f"Successfully processed and saved to {OUTPUT_TABLE}")
# Out:
#               <div>
#                   <p><a href="https://console.cloud.google.com/dataproc/interactive/us-central1/sc-20260213-163237-qhkzgg/sparkApplications/application;associatedSqlOperationId=767f0d95-79b4-48b4-9f51-6cf96e1f41cb?project=lgbaeza-202310">Spark Query</a> (Operation: 767f0d95-79b4-48b4-9f51-6cf96e1f41cb)</p>
#               </div>
# Successfully processed and saved to lgbaeza-202310.retail_geodemo.retail_sale_point_enriched

# %%
# %%bigquery
# # Save with the right format
# CREATE OR REPLACE TABLE retail_geodemo.retail_sale_point_enriched_g as
# select * except(wkt), ST_GEOGFROMTEXT(wkt) AS geopoint_location from retail_geodemo.retail_sale_point_enriched
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ## 4. Finding closes areas of analysis to the data points

# %%
# %%bigquery
# CREATE OR REPLACE TABLE `retail_geodemo.point_to_nearest_area` AS
# WITH distances AS (
#   SELECT
#     p.id AS point_id,
#     p.direccion,
#     a.number_area,
#     p.geopoint_location,
#     -- ST_DISTANCE calcula la distancia mínima en metros entre el punto y el borde del polígono
#     ST_DISTANCE(p.geopoint_location, a.area_polygon) AS distance_meters
#   FROM
#     `retail_geodemo.retail_sale_point_enriched_g` AS p
#   CROSS JOIN
#     `retail_geodemo.retail_areas` AS a
# )
# SELECT
#   * except (ranking)
# FROM (
#   SELECT
#     *,
#     -- Numeramos las filas por cada punto, ordenadas por la distancia más corta
#     ROW_NUMBER() OVER(PARTITION BY point_id ORDER BY distance_meters ASC) as ranking
#   FROM distances
# )
# -- Filtramos para obtener solo el registro #1 (el más cercano)
# WHERE ranking = 1;
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%bigquery
# select
#   point_id, direccion, p.number_area,
#   a.area_polygon, p.geopoint_location
# from retail_geodemo.point_to_nearest_area  p
# INNER JOIN retail_geodemo.retail_areas a using (number_area)
# limit 10
# Out:
# Query is running:   0%|          |
# Downloading:   0%|          |
#                                point_id              direccion number_area  \
# 0  7f64c377-0017-4747-a700-65f41789c78b  Avenida Libertad 1732       8A2D4
# 1  183b904d-21c0-46e4-8c0e-8d0c1a3c7827  Avenida Libertad 2056       8A2D4
# 2  3cb64646-3a64-4b34-bdcb-2d8ce4685c9b  Avenida Libertad 1748       8A2D4
# 3  8bb3ce53-c944-4201-8ffa-294b432d0f05  Avenida Libertad 2630       8A2D4
# 4  6b77c477-43a3-46d2-b040-33b3b9b31514  Avenida Libertad 1644       8A2D4
# 5  f4a2d2d4-5c59-4261-8242-2e5b4168c14e  Avenida Libertad 1838       8A2D4
# 6  3be6d85f-107b-42ad-bde2-0baa9254c40a  Avenida Libertad 2536       8A2D4
# 7  58701e2c-0aa5-4de8-9682-8857fea88bec  Avenida Libertad 2026       8A2D4
# 8  5964fa07-c74d-46a7-899f-0c0c6d5f8380  Avenida Libertad 1890       8A2D4
# 9  ed52d73a-85a2-4950-bd17-941a9cc30b1b  Avenida Libertad 2366       8A2D4
#
#                                         area_polygon  \
# 0  POLYGON((-72.3 -32.7, -72.2 -32.7, -72.2 -32.6...
# 1  POLYGON((-72.3 -32.7, -72.2 -32.7, -72.2 -32.6...
# 2  POLYGON((-72.3 -32.7, -72.2 -32.7, -72.2 -32.6...
# 3  POLYGON((-72.3 -32.7, -72.2 -32.7, -72.2 -32.6...
# 4  POLYGON((-72.3 -32.7, -72.2 -32.7, -72.2 -32.6...
# 5  POLYGON((-72.3 -32.7, -72.2 -32.7, -72.2 -32.6...
# 6  POLYGON((-72.3 -32.7, -72.2 -32.7, -72.2 -32.6...
# 7  POLYGON((-72.3 -32.7, -72.2 -32.7, -72.2 -32.6...
# 8  POLYGON((-72.3 -32.7, -72.2 -32.7, -72.2 -32.6...
# 9  POLYGON((-72.3 -32.7, -72.2 -32.7, -72.2 -32.6...
#
#                 geopoint_location
# 0  POINT(-71.5485564 -33.0081471)
# 1  POINT(-71.5485564 -33.0081471)
# 2  POINT(-71.5485564 -33.0081471)
# 3  POINT(-71.5485564 -33.0081471)
# 4  POINT(-71.5485564 -33.0081471)
# 5  POINT(-71.5485564 -33.0081471)
# 6  POINT(-71.5485564 -33.0081471)
# 7  POINT(-71.5485564 -33.0081471)
# 8  POINT(-71.5485564 -33.0081471)
# 9  POINT(-71.5485564 -33.0081471)

# %% [markdown]
# We create a table for visualizing both areas and points.

# %%
# %%bigquery
# create or replace table retail_geodemo.retail_sale_point_areas as
# with analysis_dedup as (
#   with analysis as (
#   select
#     point_id, direccion, p.number_area,
#     ST_AsText(a.area_polygon) area_polygon, ST_AsText(p.geopoint_location) geopoint_location
#   from retail_geodemo.point_to_nearest_area  p
#   INNER JOIN retail_geodemo.retail_areas a using (number_area)
#   )
#   select number_area, area_polygon from analysis
#   union all
#   select number_area, geopoint_location from analysis group by 1,2
# )
# select number_area, ST_GEOGFROMTEXT(area_polygon) area_polygon from analysis_dedup
# Out:
# Query is running:   0%|          |
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### 4.1 Visual analysis
# We can see how the data poings are groupped into the closest locations defined by us.
#
# ![polygons_grouped.png](polygons_grouped.png)

# %% [markdown]
# ## Lastly: What's Next
# * The cross join can be optimized with other methods for large scale scenarios
# * Further analysis can be made other than only the closes area.
# * Additional data can be brought into the analysis using BigQuery Geospatial Analytics functions. If you are a wine fan, you can find an example about geographic feature analysis with a sample agricultural use case as part of the [BigQuery Data Science Book.](https://github.com/GoogleCloudPlatform/ai-ml-recipes/blob/main/notebooks/analytics/assessing_risks_geospatial_bqml.ipynb)
